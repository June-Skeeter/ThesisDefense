# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
fig,ax=plt.subplots(1,2,figsize=(7,4))
# ax.plot()
CO2 = [-1,2,3]
CO2_N = ['Net Ecosystem\nExchange','Ecosystem\nRespiration','Gross Primary\nProductivity']
colors = ['yellow','brown','green']



for i in range(0,3):
    ax[0].bar(i,CO2[i],color=colors[i],edgecolor='k')
    ax[0].text(i,CO2[i]/2,CO2_N[i],ha='center')

CH4 = [1,2,3]
CH4_N = ['NME','Methanogenesis','Methanotrophy']

plt.tight_layout()
